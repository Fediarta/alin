# %% [markdown]
# # Tugas 1

# %% [markdown]
# # Komputasi Aljabar Linier
# ### Sistem Persamaan Linier Dengan Metode Eliminasi Gauss

# %% [markdown]
# **SISTEM PERSAMAAN LINIER**
#
#   Sistem Persamaan Linier adalah kumpulan persamaan-persamaan linier yang memiliki variable-variable yang sama.Sistem persamaan linier dapat diselesaikan dengan beberapa metode penyelesaian sistem persamaan linier seperti : metode grafik ,metode substitusi,metode eliminasi gauss,dll.
#
#
# **ELIMINASI GAUSS**
#
#   Eliminasi Gauss adalah suatu metode untuk
# mengoperasikan nilai-nilai di dalam matriks sehingga
# menjadi matriks yang lebih sederhana lagi.Dengan
# melakukan operasi baris sehingga matriks tersebut menjadi
# matriks yang baris. Ini dapat digunakan sebagai salah satu
# metode penyelesaian persamaan linear dengan
# menggunakan matriks. Caranya dengan mengubah
# persamaan linear tersebut ke dalam matriks teraugmentasi
# dan mengoperasikannya. Setelah menjadi matriks baris,
# lakukan substitusi balik untuk mendapatkan nilai dari
# variabel-variabel tersebut.
# metode eliminasi Gauss menggunakan sejumlah operasi
# baris elementer
# (OBE):
# 1. Menukar posisi dua buah persamaan (dua barismatriks augmented)
# 2. Menambah sebuah persamaan (baris matriks augmented) dengan suatu kelipatan persamaan lain (baris lain)
# 3. Mengalikan sebuah persamaan (baris matriks augmented)  dengan sebarang konstanta tak nol.
#
#
#
# **Jenis-jenis Matriks**
#
#
# 1.Matriks Segitiga Atas

# %%
import numpy as np
A=np.array([[3,2,1],[0,4,5],[0,0,1]])
print (A)
# Out:
# [[3 2 1]
#  [0 4 5]
#  [0 0 1]]

# %% [markdown]
# 2.Matriks Eselon Baris

# %%
import numpy as np
B=np.array([[1,2,3],[0,1,5],[0,0,1]])
print (B)
# Out:
# [[1 2 3]
#  [0 1 5]
#  [0 0 1]]

# %% [markdown]
# 3.Matriks Identitas / Matriks Eselon Baris Tereduksi

# %%
import numpy as np
C=np.array([[1,0,0],[0,1,0],[0,0,1]])
print (C)
# Out:
# [[1 0 0]
#  [0 1 0]
#  [0 0 1]]

# %% [markdown]
# CONTOH
# Selesaikan persamaan berikut ini dengan metode Eliminasi Gauss
#
# $$
# 8x_1+9x_2+x_3=19\\
# x_1+2x_2+3x_3=9\\
# 2x_1+x_2+x_3=5\\
# $$
#
# untuk penyelesaiannya yang pertama deklarasikan fungsi RowSwap,RowScale,RowAdd yang telah dibuat

# %%
def RowSwap(A,k,l):
# =============================================================================
#     A is a NumPy array.  RowSwap will return duplicate array with rows
#     k and l swapped.
# =============================================================================
    m = A.shape[0]  # m is number of rows in A
    n = A.shape[1]  # n is number of columns in A

    B = np.copy(A).astype('float64')

    for j in range(n):
        temp = B[k][j]
        B[k][j] = B[l][j]
        B[l][j] = temp

    return B

def RowScale(A,k,scale):
# =============================================================================
#     A is a NumPy array.  RowScale will return duplicate array with the
#     entries of row k multiplied by scale.

#A: Matriks numpy yang akan dimodifikasi.
#k: Nomor baris yang akan diubah.
#scale: Skalar yang akan digunakan untuk mengalikan setiap elemen dalam baris ke-k.
# =============================================================================
    m = A.shape[0]  # m is number of rows in A
    n = A.shape[1]  # n is number of columns in A

    B = np.copy(A).astype('float64')

    for j in range(n):
        B[k][j] *= scale

    return B

def RowAdd(A,k,l,scale):
# =============================================================================
#     A is a numpy array.  RowAdd will return duplicate array with row
#     l modifed.  The new values will be the old values of row l added to
#     the values of row k, multiplied by scale.

#     A adalah matriks numpy yang akan dimodifikasi.
#k adalah nomor baris yang akan digunakan sebagai referensi.
#l adalah nomor baris yang akan dimodifikasi.
#scale adalah skalar yang akan digunakan untuk mengalikan baris ke-k sebelum ditambahkan ke baris ke-l.
# =============================================================================
    m = A.shape[0]  # m is number of rows in A
    n = A.shape[1]  # n is number of columns in A

    B = np.copy(A).astype('float64')

    for j in range(n):
        B[l][j] += B[k][j]*scale

    return B

# %% [markdown]
# **import numpy kemudian deklarasikan nama variable untuk Array yang diberi nama A**

# %%
import numpy as np
A=np.array([[8,9,1,19],[1,2,3,9],[2,1,1,5]])
print (A)
# Out:
# [[ 8  9  1 19]
#  [ 1  2  3  9]
#  [ 2  1  1  5]]

# %%
# tukarkan baris 0 dan 1
A1=RowSwap(A,0,1)
print(A1)
# Out:
# [[ 1.  2.  3.  9.]
#  [ 8.  9.  1. 19.]
#  [ 2.  1.  1.  5.]]

# %%
# kalikan baris 0 dengan -8 kemudian hasilnya ditambahkan ke baris 1
A2=RowAdd(A1,0,1,-8)
print(A2)
# Out:
# [[  1.   2.   3.   9.]
#  [  0.  -7. -23. -53.]
#  [  2.   1.   1.   5.]]

# %%
# kalikan baris 0 dengan -2 kemudian hasilnya ditambahkan ke baris 2
A3=RowAdd(A2,0,2,-2)
print(A3)
# Out:
# [[  1.   2.   3.   9.]
#  [  0.  -7. -23. -53.]
#  [  0.  -3.  -5. -13.]]

# %%
# kalikan baris 1 dengan -1/7
A4=RowScale(A3,1,-1/7)
print(A4)
# Out:
# [[  1.           2.           3.           9.        ]
#  [ -0.           1.           3.28571429   7.57142857]
#  [  0.          -3.          -5.         -13.        ]]

# %%
# kalikan baris 1 dengan 3 kemudian hasilnya ditambahkan ke baris 2
A5=RowAdd(A4,1,2,3)
print(A5)
# Out:
# [[ 1.          2.          3.          9.        ]
#  [-0.          1.          3.28571429  7.57142857]
#  [ 0.          0.          4.85714286  9.71428571]]

# %%
# kalikan baris 2 dengan 1/4.85714286
A6=RowScale(A5,2,1/4.85714286)
print(A6)
# Out:
# [[ 1.          2.          3.          9.        ]
#  [-0.          1.          3.28571429  7.57142857]
#  [ 0.          0.          1.          2.        ]]

# %% [markdown]
# Dari matriks terakhir tersebut sudah berbentuk matriks eselon baris. Selanjutnya tinggal mengubahnya kembali menjadi sistem persamaan linear
# $$
# x_1+2x_2+3x_3=9\\
# x_2+3.28571429x_3=7.57142857\\
# x_3=2\\
# $$

# %%
 # penyelesaian Persamaan
x3 = 2
print('x3:', x3)
x2 = 7.57142857-(3.28571429*x3)
print("x2:", round(x2))
x1 = 9 - 2*x2 - 3*x3
print('x1:', round(x1))
# Out:
# x3: 2
# x2: 1
# x1: 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Koefisien untuk  persamaan bidang
a1, b1, c1, r1 = 1, 2, 3, 9
a2, b2, c2, r2 = 0, 1, 13, 27
a3, b3, c3, r3 = 0, 0, 1, 2

# Buat data x, y
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

# Buat grid x, y
X, Y = np.meshgrid(x, y)

# Hitung nilai z sesuai  persamaan bidang
Z1 = (r1 - a1*X - b1*Y) / c1
Z2 = (r2 - a2*X - b2*Y) / c2
Z3 = (r3 - a3*X - b3*Y) / c3

# Plot persamaan bidang dalam 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot bidang
ax.plot_surface(X, Y, Z1, alpha=0.5, rstride=100, cstride=100, color='y')
ax.plot_surface(X, Y, Z2, alpha=0.5, rstride=100, cstride=100, color='m')
ax.plot_surface(X, Y, Z3, alpha=0.5, rstride=100, cstride=100, color='c')

# Titik perpotongan
A = np.array([[a1, b1, c1], [a2, b2, c2], [a3, b3, c3]])
B = np.array([r1, r2, r3])
intersect = np.linalg.solve(A, B)
ax.scatter(intersect[0], intersect[1], intersect[2], color='black', s=100, label='Titik Perpotongan')

# Label sumbu
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Tampilkan legenda
ax.legend()

# Tampilkan plot
plt.show()
